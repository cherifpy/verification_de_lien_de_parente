# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.version
# Out:
# '3.7.10 (default, May  3 2021, 02:48:31) \n[GCC 7.5.0]'

# %%
# !cp '/content/drive/MyDrive/fiw-bs-kin_processed.zip' 'fiw-bs-kin.zip'

# %%
from zipfile import ZipFile

with ZipFile('fiw-bs-kin.zip') as zip:
    zip.extractall('Data')
    print('File is unzipped in temp folder')
# Out:
# File is unzipped in temp folder

# %%
"""
  Importer les bibliotheques nécessaires
  
"""

import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from imageio import imread
from PIL import Image
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense,Input, Conv2D, MaxPooling2D, Flatten, Lambda,Dropout,Concatenate
from tensorflow.keras.optimizers import Adam, SGD
import tensorflow.keras.backend as bk
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.metrics import RootMeanSquaredError
from keras.models import load_model 
import cv2
from datetime import datetime
from tensorflow.keras import regularizers
from random import randint
from time import time
from tensorflow.keras import layers
from keras.models import load_model

# %%
def ReadFile(file_path):
    with open(file_path, 'rb') as bin_file:
        return bin_file.read()

def ChargerDonneesRelation(kinShip):
  train_setX,train_setY,test_setX,test_setY = [],[],[],[]
    
  train_path = "/content/Data/Dataset/bs-kin/train-faces/"
  test_path = "/content/Data/Dataset/bs-kin/test-faces/"
  
  dataTrain = pd.read_csv("Data/Dataset/bs-kin/train-"+kinShip+".txt" ,delimiter=" ")
  dataTrain = dataTrain.sample(frac=1).reset_index(drop=True)
  dataTrain.columns = ['parent', 'child', 'Kinship']
  dataTest = pd.read_csv("Data/Dataset/bs-kin/test-"+kinShip+".txt" ,delimiter=" ")
  dataTest = dataTest.sample(frac=1).reset_index(drop=True)
  dataTest.columns = ['parent', 'child', 'Kinship']

  for i in range(len(dataTrain)):
      pimg = ReadFile(train_path + dataTrain.parent[i])
      cimg = ReadFile(train_path + dataTrain.child[i])
      train_setX.append((pimg, cimg))
      train_setY.append(dataTrain.Kinship[i])
  
  for i in range(len(dataTest)):
      pimg = ReadFile(test_path + dataTest.parent[i])
      cimg = ReadFile(test_path + dataTest.child[i])
      test_setX.append((pimg, cimg))
      test_setY.append(dataTest.Kinship[i])

  return train_setX, train_setY, test_setX, test_setY

# %%
def L1_Shape(shape):
      return shape[0]

def build_CNN(input_shape):
  """
    Ici on cree notre sous-reseaux de neurones 
    
    Comme argument: 
      Input_shape: dimensionne d'une image  

  """
  
  ConvNet = Sequential(name='Feature_extraction')
  ConvNet.add(Conv2D(16, kernel_size=3, activation='relu', padding='same', 
                     input_shape=input_shape))
  ConvNet.add(MaxPooling2D())
  ConvNet.add(Conv2D(32, kernel_size=3, activation='relu', padding='same'))
  ConvNet.add(MaxPooling2D())
  ConvNet.add(Conv2D(64, kernel_size=3, activation='relu', padding='same'))
  ConvNet.add(MaxPooling2D())
  ConvNet.add(Flatten())

  print("======================Description du modele CNN======================")
  ConvNet.summary()

  return ConvNet
  

def build_SiameseConNet(input_shape):
  """
    Ici on cree notre reseaux de neurones 
    
    Comme argument: 
      Input_shape: dimensionne d'une image  

  """


  ConvNet = build_CNN(input_shape)
  #**********************Creation des entrees********************** 
  #Entree 1
  input_l = Input(shape=input_shape)
  #Entree 2
  input_r = Input(shape=input_shape)

  #recuperation des vecteurs de caracteristiques 
  #Feature-Vector 1 
  encoded_l = ConvNet(input_l)
  #Feature-Vector 2
  encoded_r = ConvNet(input_r)

  # Creation de la couche de fussionne 
  Merged = Lambda(lambda tensor: bk.abs(tensor[0] - tensor[1]), output_shape=L1_Shape)

  #Connecter la couche du fussionne au sortie des deux reseaux jumeaux
  couche_fussionne = Merged([encoded_l, encoded_r])

  #Couche de sortie 
  prediction = Dense(1, activation='sigmoid')(couche_fussionne)

  # Creation du modele siamois 
  SiameseNet = Model(name='Siamese_CNN',inputs=[input_l,input_r],outputs=prediction)
  print("====================== Description du modele ======================")
  SiameseNet.summary()

  return SiameseNet

# %%
def decode_jpeg(data, img_shape):
    """
      Cette fonction decode les images 
      args:
        data: le code de l'image
        img_shape: dimensionne des images  
    """
    src = cv2.imdecode(np.frombuffer(data, dtype=np.uint8), cv2.IMREAD_COLOR)
    dst = np.zeros(src.shape, np.float32)
    dst[:, :, 0] = src[:, :, 2]
    dst[:, :, 1] = src[:, :, 1]
    dst[:, :, 2] = src[:, :, 0]
    return (cv2.resize(dst, (img_shape[0], img_shape[1]))/255).astype(np.float32)

def Train(model, trainset_x, trainset_y, nb_epochs, size_batch, path, save_each_epoch=False):
    """
      Fonction d'entrainement du modele 
      args:
        model: le model a entraîner
        trainset_x: ensemble de donnes X 
        trainset_y:ensemble de donnes Y  
        nb_epochs: nombre d'epoch sur lequel on va entrainer 
        size_batch: taille de l'ensemble de donnnees a utiliser a chaque iteration sur le datasets
        path: l'emplacement ou on veux enregistre le modele
        save_each_epoch: est ce que on veux enregistre le modele pour chaque epochs 
    """
    resultats = []
    filepath = path+".h5"

    checkpoint = ModelCheckpoint(filepath,monitor='val_accuracy', 
                                verbose=1,save_best_only=True, 
                                mode='max')

    reduce_on_plateau = ReduceLROnPlateau(monitor="val_accuracy", mode="max", 
                                            factor=0.1,patience=2,verbose=1)

    checkpoint_ = ModelCheckpoint(filepath, monitor='val_accuracy',verbose=1, 
                                    save_best_only=False,save_weights_only=False, 
                                    mode='auto', save_freq = 'epoch')

    if save_each_epoch: 
        calls = [checkpoint_, reduce_on_plateau]
        
    else : 
        calls = [checkpoint, reduce_on_plateau]

    model.compile(optimizer=SGD(0.01), loss='binary_crossentropy', metrics=["accuracy"])
    img_shape = model.input_shape[0][1:] 
    #================= Creation du dataset de validation =================
    validation_split=0.2
    assert len(trainset_x) == len(trainset_y)
    data_size = len(trainset_x)
    valid_size = int(validation_split * data_size)
    train_size = data_size - valid_size
    train_x = trainset_x[:train_size]
    train_y = trainset_y[:train_size]
    valid_x = trainset_x[train_size:]
    valid_y = trainset_y[train_size:]

    #================= Calcule du nombre d'iteration par epoch =================
    nb_iterations_t = train_size // size_batch
    nb_iterations_v = valid_size // size_batch
    batch_x = [np.empty((size_batch, img_shape[0], img_shape[1], img_shape[2]), np.float32), np.empty((size_batch, img_shape[0], img_shape[1], img_shape[2]), np.float32)]
    batch_y = np.empty((size_batch, 1), np.float32)

    for call in calls:
        call.on_train_begin()
        call.model = model
    for epochs in range(nb_epochs):
        start = time()
        print('Epoch %d/%d'%(epochs+1, nb_epochs))
        loss = 0
        accu = 0
        for iterations in range(nb_iterations_t):
          # Creation du batch pour entrainement
          for i in range(size_batch):
              sample = randint(0, train_size-1)
              batch_x[0][i, :, :, :] = decode_jpeg(train_x[sample][0], img_shape)
              batch_x[1][i, :, :, :] = decode_jpeg(train_x[sample][1], img_shape)
              batch_y[i] = train_y[sample]
          # Entrainer sur le batch cree
          result = model.train_on_batch(batch_x, batch_y)
          loss = loss + result[0]
          accu = accu + result[1]
        # Calculer la performance obtenue avec ce batch
        loss = loss / nb_iterations_t
        accu = accu / nb_iterations_t
        val_loss = 0
        val_accu = 0
        for iterations in range(nb_iterations_v):
          #Creation du batch pour validation  
          for i in range(size_batch):
              sample = randint(0, valid_size-1)
              batch_x[0][i, :, :, :] = decode_jpeg(valid_x[sample][0], img_shape)
              batch_x[1][i, :, :, :] = decode_jpeg(valid_x[sample][1], img_shape)
              batch_y[i] = valid_y[sample]
          # Valider sur ce batch seulement
          result = model.test_on_batch(batch_x, batch_y)
          val_loss = val_loss + result[0]
          val_accu = val_accu + result[1]
        # Calculer la performance obtenue avec ce batch
        val_loss = val_loss / nb_iterations_v
        val_accu = val_accu / nb_iterations_v

        resultats.append({"epoch":epochs, "loss":loss,"accu":accu,"val_loss":val_loss,"val_accu":val_accu})
        print('%ds - loss: %.04f - accuracy: %.04f - val_loss: %.04f - val_accuracy: %.04f'%(int(time()-start), loss, accu, val_loss, val_accu))
        for call in calls:
            call.on_epoch_end(epochs+1, logs={'val_accuracy': val_accu})
    return resultats

# %%
def test(model, test_x, test_y,size_batch):
  """
    ici on test notre modele 
        test_x: ensemble de donnes X 
        test_y:ensemble de donnes Y  
        size_batch: taille de l'ensemble de donnnees a utiliser a chaque iteration sur le datasets

  """
  test_size = len(test_x)
  img_shape = model.input_shape[0][1:] 
  # Nombre d'iterations training
  nb_iterations_v = test_size // size_batch
  test_loss = 0
  test_accu = 0
  batch_x = [np.empty((size_batch, img_shape[0], img_shape[1], img_shape[2]),np.float32),
              np.empty((size_batch, img_shape[0], img_shape[1], img_shape[2]), np.float32)]
  batch_y = np.empty((size_batch, 1), np.float32)
  for iterations in range(nb_iterations_v):
      for i in range(size_batch):
          sample = randint(0, test_size-1)
          batch_x[0][i, :, :, :] = decode_jpeg(test_x[sample][0], img_shape)
          batch_x[1][i, :, :, :] = decode_jpeg(test_x[sample][1], img_shape)
          batch_y[i] = test_y[sample]
      # tester sur le batch
      result = model.test_on_batch(batch_x, batch_y)
      test_loss = test_loss + result[0]
      test_accu = test_accu + result[1]
  # Calculer les mésures de performance moyennes
  test_loss = test_loss / nb_iterations_v
  test_accu = test_accu / nb_iterations_v

  return (test_loss, test_accu)

# %%
"""
    ici on affiche les resultat sous forme de graphe avec ces 2 fonctions 
      path_file: emplacement du fichier csv
  """
def plot_loss_resultat(path_file,nom_image):
  

  columns = ['epochs','loss','accu','val_loss','val_accu']
  resultat = pd.read_csv(path_file)
  resultat.columns = columns
  fig, ax = plt.subplots()
  fig.text(0.5,0.9,'Loss',fontsize=15,horizontalalignment='center')
  ax.plot(resultat.epochs,resultat.loss,c='r',label='train')
  ax.plot(resultat.epochs,resultat.val_loss,c="green",label='valid')
  ax.set_xlabel('Epoch')
  ax.set_ylabel('Loss')
  ax.legend()
  fig.savefig(path_file[:-12]+nom_image)

def plot_accuracy_resultat(path_file,nom_image):

  columns = ['epochs','loss','accu','val_loss','val_accu']
  resultat = pd.read_csv(path_file)
  resultat.columns = columns

  fig, ax = plt.subplots()
  fig.text(0.5,0.9,'Accuracy',fontsize=15,horizontalalignment='center')
  ax.plot(resultat.epochs,resultat.accu,c='r',label='train')
  ax.plot(resultat.epochs,resultat.val_accu,c="green",label='valid')
  ax.set_xlabel('Epoch')
  ax.set_ylabel('Accuracy')
  ax.legend()
  fig.savefig(path_file[:-12]+nom_image)

# %%
def main():
  
  relations = ['fs','fd','ms','md']

  nom_fichiers = []

  dtime = datetime.now().strftime("%m-%d-%Y_%H:%M:%S")

  for relation in relations:
    print("Creation du modele...")
    modele =  build_SiameseConNet((128, 128, 3))

    print("Chargement des donnees...")
    TrainX, TrainY, TestX, TestY = ChargerDonneesRelation(relation)

    print("Debut de l'entrainemtn...")
    resultat = Train(modele, TrainX, TrainY, 15, 100,
                     "/content/drive/MyDrive/Model/Best_/"+dtime+relation+"/model",save_each_epoch=False)


    #enregistre le resultat de chaque epoche pour chaque modele cree
    with open("/content/drive/MyDrive/Model/Best_/"+dtime+relation+"/rs_model.csv", 'w') as f: 
      for epoch in resultat:
        f.write(f"{epoch['epoch']},{epoch['loss']},{epoch['accu']},{epoch['val_loss']},{epoch['val_accu']}\n")
    #phase de tests
    loss,acc = test(modele,TestX,TestY,100)
    print("Resultat des tests",loss,acc)
    modele.save("/content/drive/MyDrive/Model/Best_/"+dtime+relation+"/model_final.h5")

# %%
main()
# Out:
# Creation du modele...
# ======================Description du modele CNN======================
# Model: "Feature_extraction"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# =================================================================
# Total params: 23,584
# Trainable params: 23,584
# Non-trainable params: 0
# _________________________________________________________________
# ====================== Description du modele ======================
# Model: "Siamese_CNN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# Feature_extraction (Sequential) (None, 16384)        23584       input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 16384)        0           Feature_extraction[0][0]
#                                                                  Feature_extraction[1][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            16385       lambda[0][0]
# ==================================================================================================
# Total params: 39,969
# Trainable params: 39,969
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Chargement des donnees...
# Debut de l'entrainemtn...
# Epoch 1/15
# 178s - loss: 0.6705 - accuracy: 0.5969 - val_loss: 0.6477 - val_accuracy: 0.6223
#
# Epoch 00002: val_accuracy improved from -inf to 0.62226, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fs/model.h5
# Epoch 2/15
# 146s - loss: 0.6231 - accuracy: 0.6443 - val_loss: 0.5889 - val_accuracy: 0.6876
#
# Epoch 00003: val_accuracy improved from 0.62226 to 0.68763, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fs/model.h5
# Epoch 3/15
# 145s - loss: 0.5645 - accuracy: 0.6924 - val_loss: 0.5353 - val_accuracy: 0.7239
#
# Epoch 00004: val_accuracy improved from 0.68763 to 0.72387, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fs/model.h5
# Epoch 4/15
# 145s - loss: 0.5226 - accuracy: 0.7268 - val_loss: 0.5226 - val_accuracy: 0.7095
#
# Epoch 00005: val_accuracy did not improve from 0.72387
# Epoch 5/15
# 146s - loss: 0.4978 - accuracy: 0.7442 - val_loss: 0.4956 - val_accuracy: 0.7292
#
# Epoch 00006: val_accuracy improved from 0.72387 to 0.72925, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fs/model.h5
# Epoch 6/15
# 144s - loss: 0.4730 - accuracy: 0.7638 - val_loss: 0.4830 - val_accuracy: 0.7451
#
# Epoch 00007: val_accuracy improved from 0.72925 to 0.74505, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fs/model.h5
# Epoch 7/15
# 144s - loss: 0.4554 - accuracy: 0.7766 - val_loss: 0.4285 - val_accuracy: 0.7951
#
# Epoch 00008: val_accuracy improved from 0.74505 to 0.79505, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fs/model.h5
# Epoch 8/15
# 144s - loss: 0.4380 - accuracy: 0.7869 - val_loss: 0.5437 - val_accuracy: 0.7381
#
# Epoch 00009: val_accuracy did not improve from 0.79505
# Epoch 9/15
# 144s - loss: 0.4231 - accuracy: 0.7989 - val_loss: 0.4336 - val_accuracy: 0.7830
#
# Epoch 00010: val_accuracy did not improve from 0.79505
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# Epoch 10/15
# 144s - loss: 0.3729 - accuracy: 0.8331 - val_loss: 0.3835 - val_accuracy: 0.8238
#
# Epoch 00011: val_accuracy improved from 0.79505 to 0.82382, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fs/model.h5
# Epoch 11/15
# 144s - loss: 0.3664 - accuracy: 0.8364 - val_loss: 0.3881 - val_accuracy: 0.8252
#
# Epoch 00012: val_accuracy improved from 0.82382 to 0.82522, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fs/model.h5
# Epoch 12/15
# 144s - loss: 0.3607 - accuracy: 0.8405 - val_loss: 0.3784 - val_accuracy: 0.8264
#
# Epoch 00013: val_accuracy improved from 0.82522 to 0.82640, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fs/model.h5
# Epoch 13/15
# 144s - loss: 0.3586 - accuracy: 0.8409 - val_loss: 0.3727 - val_accuracy: 0.8273
#
# Epoch 00014: val_accuracy improved from 0.82640 to 0.82731, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fs/model.h5
# Epoch 14/15
# 144s - loss: 0.3563 - accuracy: 0.8407 - val_loss: 0.3738 - val_accuracy: 0.8305
#
# Epoch 00015: val_accuracy improved from 0.82731 to 0.83048, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fs/model.h5
# Epoch 15/15
# 144s - loss: 0.3494 - accuracy: 0.8472 - val_loss: 0.3754 - val_accuracy: 0.8308
#
# Epoch 00016: val_accuracy improved from 0.83048 to 0.83075, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fs/model.h5
# Resultat des tests 1.0258241662612329 0.5336923071971307
# Creation du modele...
# ======================Description du modele CNN======================
# Model: "Feature_extraction"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 128, 128, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# =================================================================
# Total params: 23,584
# Trainable params: 23,584
# Non-trainable params: 0
# _________________________________________________________________
# ====================== Description du modele ======================
# Model: "Siamese_CNN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# Feature_extraction (Sequential) (None, 16384)        23584       input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16384)        0           Feature_extraction[0][0]
#                                                                  Feature_extraction[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            16385       lambda_1[0][0]
# ==================================================================================================
# Total params: 39,969
# Trainable params: 39,969
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Chargement des donnees...
# Debut de l'entrainemtn...
# Epoch 1/15
# 95s - loss: 0.6606 - accuracy: 0.6077 - val_loss: 0.6282 - val_accuracy: 0.6584
#
# Epoch 00002: val_accuracy improved from -inf to 0.65836, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fd/model.h5
# Epoch 2/15
# 95s - loss: 0.5867 - accuracy: 0.6908 - val_loss: 0.5349 - val_accuracy: 0.7507
#
# Epoch 00003: val_accuracy improved from 0.65836 to 0.75066, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fd/model.h5
# Epoch 3/15
# 95s - loss: 0.4848 - accuracy: 0.7745 - val_loss: 0.4375 - val_accuracy: 0.8095
#
# Epoch 00004: val_accuracy improved from 0.75066 to 0.80951, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fd/model.h5
# Epoch 4/15
# 95s - loss: 0.4067 - accuracy: 0.8202 - val_loss: 0.6525 - val_accuracy: 0.6230
#
# Epoch 00005: val_accuracy did not improve from 0.80951
# Epoch 5/15
# 95s - loss: 0.3638 - accuracy: 0.8422 - val_loss: 0.3392 - val_accuracy: 0.8521
#
# Epoch 00006: val_accuracy improved from 0.80951 to 0.85213, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fd/model.h5
# Epoch 6/15
# 95s - loss: 0.3298 - accuracy: 0.8597 - val_loss: 0.3231 - val_accuracy: 0.8689
#
# Epoch 00007: val_accuracy improved from 0.85213 to 0.86885, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fd/model.h5
# Epoch 7/15
# 95s - loss: 0.3050 - accuracy: 0.8726 - val_loss: 0.2853 - val_accuracy: 0.8830
#
# Epoch 00008: val_accuracy improved from 0.86885 to 0.88303, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fd/model.h5
# Epoch 8/15
# 95s - loss: 0.2889 - accuracy: 0.8793 - val_loss: 0.3042 - val_accuracy: 0.8727
#
# Epoch 00009: val_accuracy did not improve from 0.88303
# Epoch 9/15
# 95s - loss: 0.2721 - accuracy: 0.8868 - val_loss: 0.2710 - val_accuracy: 0.8910
#
# Epoch 00010: val_accuracy improved from 0.88303 to 0.89098, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fd/model.h5
# Epoch 10/15
# 95s - loss: 0.2506 - accuracy: 0.8987 - val_loss: 0.2440 - val_accuracy: 0.8985
#
# Epoch 00011: val_accuracy improved from 0.89098 to 0.89852, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fd/model.h5
# Epoch 11/15
# 95s - loss: 0.2378 - accuracy: 0.9047 - val_loss: 0.2187 - val_accuracy: 0.9148
#
# Epoch 00012: val_accuracy improved from 0.89852 to 0.91475, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fd/model.h5
# Epoch 12/15
# 95s - loss: 0.2302 - accuracy: 0.9080 - val_loss: 0.2292 - val_accuracy: 0.9041
#
# Epoch 00013: val_accuracy did not improve from 0.91475
# Epoch 13/15
# 95s - loss: 0.2177 - accuracy: 0.9138 - val_loss: 0.2090 - val_accuracy: 0.9159
#
# Epoch 00014: val_accuracy improved from 0.91475 to 0.91590, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fd/model.h5
# Epoch 14/15
# 95s - loss: 0.2060 - accuracy: 0.9207 - val_loss: 0.2241 - val_accuracy: 0.9077
#
# Epoch 00015: val_accuracy did not improve from 0.91590
# Epoch 15/15
# 95s - loss: 0.1942 - accuracy: 0.9255 - val_loss: 0.1937 - val_accuracy: 0.9254
#
# Epoch 00016: val_accuracy improved from 0.91590 to 0.92541, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31fd/model.h5
# Resultat des tests 1.8355890850226084 0.4958333303531011
# Creation du modele...
# ======================Description du modele CNN======================
# Model: "Feature_extraction"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 128, 128, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 16384)             0
# =================================================================
# Total params: 23,584
# Trainable params: 23,584
# Non-trainable params: 0
# _________________________________________________________________
# ====================== Description du modele ======================
# Model: "Siamese_CNN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# Feature_extraction (Sequential) (None, 16384)        23584       input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 16384)        0           Feature_extraction[0][0]
#                                                                  Feature_extraction[1][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            16385       lambda_2[0][0]
# ==================================================================================================
# Total params: 39,969
# Trainable params: 39,969
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Chargement des donnees...
# Debut de l'entrainemtn...
# Epoch 1/15
# 145s - loss: 0.6695 - accuracy: 0.5854 - val_loss: 0.6465 - val_accuracy: 0.6161
#
# Epoch 00002: val_accuracy improved from -inf to 0.61615, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31ms/model.h5
# Epoch 2/15
# 144s - loss: 0.6219 - accuracy: 0.6446 - val_loss: 0.5878 - val_accuracy: 0.6813
#
# Epoch 00003: val_accuracy improved from 0.61615 to 0.68128, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31ms/model.h5
# Epoch 3/15
# 147s - loss: 0.5625 - accuracy: 0.6983 - val_loss: 0.5210 - val_accuracy: 0.7347
#
# Epoch 00004: val_accuracy improved from 0.68128 to 0.73465, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31ms/model.h5
# Epoch 4/15
# 147s - loss: 0.5148 - accuracy: 0.7357 - val_loss: 0.5231 - val_accuracy: 0.7268
#
# Epoch 00005: val_accuracy did not improve from 0.73465
# Epoch 5/15
# 148s - loss: 0.4823 - accuracy: 0.7586 - val_loss: 0.4548 - val_accuracy: 0.7839
#
# Epoch 00006: val_accuracy improved from 0.73465 to 0.78385, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31ms/model.h5
# Epoch 6/15
# 147s - loss: 0.4531 - accuracy: 0.7797 - val_loss: 0.4376 - val_accuracy: 0.7903
#
# Epoch 00007: val_accuracy improved from 0.78385 to 0.79032, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31ms/model.h5
# Epoch 7/15
# 147s - loss: 0.4328 - accuracy: 0.7911 - val_loss: 0.5394 - val_accuracy: 0.7256
#
# Epoch 00008: val_accuracy did not improve from 0.79032
# Epoch 8/15
# 146s - loss: 0.4118 - accuracy: 0.8083 - val_loss: 0.4077 - val_accuracy: 0.8080
#
# Epoch 00009: val_accuracy improved from 0.79032 to 0.80802, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31ms/model.h5
# Epoch 9/15
# 147s - loss: 0.3870 - accuracy: 0.8217 - val_loss: 0.3675 - val_accuracy: 0.8411
#
# Epoch 00010: val_accuracy improved from 0.80802 to 0.84107, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31ms/model.h5
# Epoch 10/15
# 147s - loss: 0.3698 - accuracy: 0.8326 - val_loss: 0.3406 - val_accuracy: 0.8549
#
# Epoch 00011: val_accuracy improved from 0.84107 to 0.85487, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31ms/model.h5
# Epoch 11/15
# 148s - loss: 0.3482 - accuracy: 0.8433 - val_loss: 0.3819 - val_accuracy: 0.8278
#
# Epoch 00012: val_accuracy did not improve from 0.85487
# Epoch 12/15
# 147s - loss: 0.3266 - accuracy: 0.8562 - val_loss: 0.2987 - val_accuracy: 0.8689
#
# Epoch 00013: val_accuracy improved from 0.85487 to 0.86893, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31ms/model.h5
# Epoch 13/15
# 147s - loss: 0.3090 - accuracy: 0.8691 - val_loss: 0.3858 - val_accuracy: 0.8179
#
# Epoch 00014: val_accuracy did not improve from 0.86893
# Epoch 14/15
# 147s - loss: 0.2905 - accuracy: 0.8772 - val_loss: 0.2750 - val_accuracy: 0.8876
#
# Epoch 00015: val_accuracy improved from 0.86893 to 0.88759, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31ms/model.h5
# Epoch 15/15
# 147s - loss: 0.2801 - accuracy: 0.8824 - val_loss: 0.2968 - val_accuracy: 0.8757
#
# Epoch 00016: val_accuracy did not improve from 0.88759
# Resultat des tests 1.1232120005451902 0.53326530115945
# Creation du modele...
# ======================Description du modele CNN======================
# Model: "Feature_extraction"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 128, 128, 16)      448
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 16384)             0
# =================================================================
# Total params: 23,584
# Trainable params: 23,584
# Non-trainable params: 0
# _________________________________________________________________
# ====================== Description du modele ======================
# Model: "Siamese_CNN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# Feature_extraction (Sequential) (None, 16384)        23584       input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 16384)        0           Feature_extraction[0][0]
#                                                                  Feature_extraction[1][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            16385       lambda_3[0][0]
# ==================================================================================================
# Total params: 39,969
# Trainable params: 39,969
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Chargement des donnees...
# Debut de l'entrainemtn...
# Epoch 1/15
# 94s - loss: 0.6730 - accuracy: 0.5812 - val_loss: 0.6495 - val_accuracy: 0.6271
#
# Epoch 00002: val_accuracy improved from -inf to 0.62706, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31md/model.h5
# Epoch 2/15
# 93s - loss: 0.6209 - accuracy: 0.6592 - val_loss: 0.5885 - val_accuracy: 0.6863
#
# Epoch 00003: val_accuracy improved from 0.62706 to 0.68630, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31md/model.h5
# Epoch 3/15
# 94s - loss: 0.5410 - accuracy: 0.7338 - val_loss: 0.5476 - val_accuracy: 0.7469
#
# Epoch 00004: val_accuracy improved from 0.68630 to 0.74689, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31md/model.h5
# Epoch 4/15
# 93s - loss: 0.4561 - accuracy: 0.7895 - val_loss: 0.4295 - val_accuracy: 0.8092
#
# Epoch 00005: val_accuracy improved from 0.74689 to 0.80924, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31md/model.h5
# Epoch 5/15
# 94s - loss: 0.4144 - accuracy: 0.8158 - val_loss: 0.4089 - val_accuracy: 0.8066
#
# Epoch 00006: val_accuracy did not improve from 0.80924
# Epoch 6/15
# 94s - loss: 0.3752 - accuracy: 0.8345 - val_loss: 0.3634 - val_accuracy: 0.8429
#
# Epoch 00007: val_accuracy improved from 0.80924 to 0.84286, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31md/model.h5
# Epoch 7/15
# 94s - loss: 0.3575 - accuracy: 0.8438 - val_loss: 0.3599 - val_accuracy: 0.8324
#
# Epoch 00008: val_accuracy did not improve from 0.84286
# Epoch 8/15
# 93s - loss: 0.3316 - accuracy: 0.8581 - val_loss: 0.3329 - val_accuracy: 0.8637
#
# Epoch 00009: val_accuracy improved from 0.84286 to 0.86370, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31md/model.h5
# Epoch 9/15
# 94s - loss: 0.3115 - accuracy: 0.8686 - val_loss: 0.4007 - val_accuracy: 0.8362
#
# Epoch 00010: val_accuracy did not improve from 0.86370
# Epoch 10/15
# 97s - loss: 0.3066 - accuracy: 0.8698 - val_loss: 0.3224 - val_accuracy: 0.8686
#
# Epoch 00011: val_accuracy improved from 0.86370 to 0.86857, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31md/model.h5
# Epoch 11/15
# 96s - loss: 0.2919 - accuracy: 0.8779 - val_loss: 0.2798 - val_accuracy: 0.8884
#
# Epoch 00012: val_accuracy improved from 0.86857 to 0.88840, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31md/model.h5
# Epoch 12/15
# 95s - loss: 0.2714 - accuracy: 0.8891 - val_loss: 0.3115 - val_accuracy: 0.8671
#
# Epoch 00013: val_accuracy did not improve from 0.88840
# Epoch 13/15
# 95s - loss: 0.2658 - accuracy: 0.8925 - val_loss: 0.3805 - val_accuracy: 0.8444
#
# Epoch 00014: val_accuracy did not improve from 0.88840
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# Epoch 14/15
# 95s - loss: 0.2139 - accuracy: 0.9183 - val_loss: 0.2550 - val_accuracy: 0.9005
#
# Epoch 00015: val_accuracy improved from 0.88840 to 0.90050, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31md/model.h5
# Epoch 15/15
# 94s - loss: 0.2116 - accuracy: 0.9211 - val_loss: 0.2453 - val_accuracy: 0.9070
#
# Epoch 00016: val_accuracy improved from 0.90050 to 0.90697, saving model to /content/drive/MyDrive/Model/Best_/07-07-2021_12:10:31md/model.h5
# Resultat des tests 1.5275367283430257 0.5096721277862298
